# %%
from pybaseball import batting_stats, batting_stats_bref, batting_stats_range, bwar_bat, playerid_lookup, statcast_batter
import re

# %% [markdown]
# `batting_stats(start_season, end_season=None, league='all', qual=1, ind=1)`

# %%
data = batting_stats(2022, qual = 10)
data
# Out:
#       IDfg  Season               Name   Team  Age    G   AB   PA    H   1B  \
# 3    15640    2022        Aaron Judge    NYY   30  157  570  696  177   87
# 17   11493    2022      Manny Machado    SDP   29  150  578  644  172  102
# 19    9777    2022      Nolan Arenado    STL   31  148  557  620  163   90
# 9     9218    2022   Paul Goldschmidt    STL   34  151  561  651  178  102
# 15    5361    2022    Freddie Freeman    LAD   32  159  612  708  199  129
# ..     ...     ...                ...    ...  ...  ...  ...  ...  ...  ...
# 556  27459    2022     Yoshi Tsutsugo    PIT   30   50  170  193   29   23
# 362  11680    2022         Elias Diaz    COL   31  105  351  381   80   51
# 611   3269    2022      Robinson Cano  - - -   39   33  100  104   15   13
# 406   1744    2022     Miguel Cabrera    DET   39  112  397  433  101   86
# 491   3142    2022  Robinson Chirinos    BAL   38   67  195  220   35   22
#
# ...

# %%
data.loc[data['Name'] == 'Aaron Judge', ['OPS', 'wRC']]
# Out:
#      OPS  wRC
# 3  1.111  162

# %%
data[data['Name'] == 'Jose Abreu']
# Out:
#      IDfg  Season        Name Team  Age    G   AB   PA    H   1B  ...  maxEV  \
# 53  15676    2022  Jose Abreu  CHW   35  157  601  679  183  128  ...  113.0
#
#     HardHit  HardHit%  Events  CStr%   CSW%    xBA   xSLG  xwOBA  L-WAR
# 53      256     0.517     495  0.166  0.264  0.296  0.486  0.373    3.3
#
# [1 rows x 320 columns]

# %%
data.loc[data['Name'] == 'Aaron Judge', 'OPS'].values[0]
# Out:
# 1.111

# %%
data.columns
# Out:
# Index(['IDfg', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B',
#        ...
#        'maxEV', 'HardHit', 'HardHit%', 'Events', 'CStr%', 'CSW%', 'xBA',
#        'xSLG', 'xwOBA', 'L-WAR'],
#       dtype='object', length=320)

# %%
data.loc[0]
# Out:
# IDfg            15640
# Season           2022
# Name      Aaron Judge
# Team              NYY
# Age                30
#              ...
# CSW%            0.287
# xBA             0.305
# xSLG            0.706
# xwOBA           0.463
# L-WAR            11.2
# Name: 0, Length: 320, dtype: object

# %% [markdown]
# `batting_stats_bref(season)`

# %%
bref = batting_stats_bref(2022)
bref
# Out:
#                   Name  Age  #days            Lev                    Tm    G  \
# 1            CJ Abrams   21    282         Maj-NL  San Diego,Washington   90
# 2    Jos\xc3\xa9 Abreu   35    282         Maj-AL               Chicago  157
# 3     Ronald Acuna Jr.   24    271         Maj-NL               Atlanta  123
# 4         Willy Adames   26    281         Maj-NL             Milwaukee  139
# 5          Riley Adams   26    282         Maj-NL            Washington   48
# ..                 ...  ...    ...            ...                   ...  ...
# 722         Juan Yepez   24    278         Maj-NL             St. Louis   78
# 723        Jared Young   26    292         Maj-NL               Chicago    6
# 724        Seby Zavala   28    291         Maj-AL               Chicago   61
# 725     Bradley Zimmer   29    281  Maj-AL,Maj-NL  Philadelphia,Toronto  109
# 726        Mike Zunino   31    399         Maj-AL             Tampa Bay   36
#
# ...

# %% [markdown]
# `bwar_bat(return_all = False)`

# %%
bwar = bwar_bat()
bwar
# Out:
#            name_common    mlb_ID  player_ID  year_ID team_ID  stint_ID lg_ID  \
# 0        David Aardsma  430911.0  aardsda01     2004     SFG         1    NL
# 1        David Aardsma  430911.0  aardsda01     2006     CHC         1    NL
# 2        David Aardsma  430911.0  aardsda01     2007     CHW         1    AL
# 3        David Aardsma  430911.0  aardsda01     2008     BOS         1    AL
# 4        David Aardsma  430911.0  aardsda01     2009     SEA         1    AL
# ...                ...       ...        ...      ...     ...       ...   ...
# 121412  Dutch Zwilling  124791.0  zwilldu01     1915     CHI         1    FL
# 121413  Dutch Zwilling  124791.0  zwilldu01     1916     CHC         1    NL
# 121414       Tony Zych  543964.0   zychto01     2015     SEA         1    AL
# 121415       Tony Zych  543964.0   zychto01     2016     SEA         1    AL
# 121416       Tony Zych  543964.0   zychto01     2017     SEA         1    AL
#
# ...

# %%
bwar_bat(return_all = True)
# Out:
#            name_common   age    mlb_ID  player_ID  year_ID team_ID  stint_ID  \
# 0        David Aardsma  22.0  430911.0  aardsda01     2004     SFG         1
# 1        David Aardsma  24.0  430911.0  aardsda01     2006     CHC         1
# 2        David Aardsma  25.0  430911.0  aardsda01     2007     CHW         1
# 3        David Aardsma  26.0  430911.0  aardsda01     2008     BOS         1
# 4        David Aardsma  27.0  430911.0  aardsda01     2009     SEA         1
# ...                ...   ...       ...        ...      ...     ...       ...
# 121412  Dutch Zwilling  26.0  124791.0  zwilldu01     1915     CHI         1
# 121413  Dutch Zwilling  27.0  124791.0  zwilldu01     1916     CHC         1
# 121414       Tony Zych  24.0  543964.0   zychto01     2015     SEA         1
# 121415       Tony Zych  25.0  543964.0   zychto01     2016     SEA         1
# 121416       Tony Zych  26.0  543964.0   zychto01     2017     SEA         1
#
# ...

# %%
bwar[bwar['pitcher'] == 'N']
# Out:
#            name_common    mlb_ID  player_ID  year_ID team_ID  stint_ID lg_ID  \
# 9          Henry Aaron  110001.0  aaronha01     1954     MLN         1    NL
# 10         Henry Aaron  110001.0  aaronha01     1955     MLN         1    NL
# 11         Henry Aaron  110001.0  aaronha01     1956     MLN         1    NL
# 12         Henry Aaron  110001.0  aaronha01     1957     MLN         1    NL
# 13         Henry Aaron  110001.0  aaronha01     1958     MLN         1    NL
# ...                ...       ...        ...      ...     ...       ...   ...
# 121399    Paul Zuvella  124789.0  zuvelpa01     1991     KCR         1    AL
# 121410  Dutch Zwilling  124791.0  zwilldu01     1910     CHW         1    AL
# 121411  Dutch Zwilling  124791.0  zwilldu01     1914     CHI         1    FL
# 121412  Dutch Zwilling  124791.0  zwilldu01     1915     CHI         1    FL
# 121413  Dutch Zwilling  124791.0  zwilldu01     1916     CHC         1    NL
#
# ...

# %% [markdown]
# `playerid_lookup(last, first=None, fuzzy=False)`

# %%
playerid_lookup('ortiz', 'david')
# Out:
# Gathering player lookup table. This may take a moment.
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0     ortiz      david     120074  ortid001  ortizda01            745
#
#    mlb_played_first  mlb_played_last
# 0            1997.0           2016.0

# %% [markdown]
# `statcast_batter(start_dt=[yesterday's date], end_dt=None, player_id)`

# %%
data = statcast_batter('2008-04-01', '2017-07-15', player_id = 120074)
data
# Out:
# Gathering Player Data
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0            CH  2014-03-31           84.1          -1.85           7.05
# 1            CH  2014-03-31           83.5          -1.82           7.05
# 2            CH  2014-03-31           84.4          -1.88           7.09
# 3            FF  2014-03-31           94.2          -2.12           6.87
# 4            FC  2014-03-31           94.4          -2.17           6.76
# ...         ...         ...            ...            ...            ...
# 7539         FS  2014-04-02           82.9          -0.77           6.79
# 7540         FS  2014-04-02           84.8          -0.55           6.67
# 7541         IN  2014-04-02           78.8          -3.49           6.18
# 7542         FF  2014-04-02           92.1          -0.72           6.77
# 7543         IN  2014-04-02           77.1          -3.57           6.21
#
# ...
